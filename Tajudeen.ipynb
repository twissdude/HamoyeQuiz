# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,3))
plt.xticks(rotation = 120)
data = fuel_df
fuel_df = pd.read_csv(r'C:\Users\user\Desktop\fuel_ferc1.csv')
sns.barplot(data['report_year'], data['fuel_cost_per_unit_burned'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
fuel_df = pd.read_csv(r'C:\Users\user\Desktop\fuel_ferc1.csv')
print(fuel_df.count())
# Out:
# record_id                       29523
# utility_id_ferc1                29523
# report_year                     29523
# plant_name_ferc1                29523
# fuel_type_code_pudl             29523
# fuel_unit                       29343
# fuel_qty_burned                 29523
# fuel_mmbtu_per_unit             29523
# fuel_cost_per_unit_burned       29523
# fuel_cost_per_unit_delivered    29523
# fuel_cost_per_mmbtu             29523
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,3))
plt.xticks(rotation = 120)
data = fuel_df
fuel_df = pd.read_csv(r'C:\Users\user\Desktop\fuel_ferc1.csv')
sns.barplot(data['report_year'], data['fuel_cost_per_unit_delivered'])

# %%
import seaborn as sns
sns.kdeplot(fuel_df['fuel_cost_per_unit_burned'], shade=True, color='y')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
fuel_df = pd.read_csv(r'C:\Users\user\Desktop\fuel_ferc1.csv')
print(fuel_df.isnull().sum())
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64
